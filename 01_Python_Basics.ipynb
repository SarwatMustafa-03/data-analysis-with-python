# %% [markdown]
# <a href="https://colab.research.google.com/github/SarwatMustafa-03/data-analysis-with-python/blob/main/01_Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## variable

# %%
print("sara")
# Out:
# sara

# %%
name="anum"
print(name)
# Out:
# anum

# %%
name="saro"
age=22
city="karachi"
print(f"I'm {name}, with an age of {age}, nowadays I'm in {city}")
# Out:
# I'm saro, with an age of 22, nowadays I'm in karachi

# %% [markdown]
# ## user input

# %%
name = input("what is your name: ")
age = input("what is your age: "),
# Out:
# what is your name: saro
# what is your age: 22

# %% [markdown]
# ## basic calculation

# %%
user1=input("enter first number:")
user2=input("enter second number:")
user1=int(user1)
user2=int(user2)
print(user1+user2)
print(user1-user2)
print(user1*user2)
print(user1/user2)
# Out:
# enter first number:3
# enter second number:2
# 5
# 1
# 6
# 1.5

# %% [markdown]
# ## sqaure & cube

# %%
num=input("enter number:")
num=int(num)
print(num**2)
print(num**3),
# Out:
# enter number:5
# 25
# 125
# (None,)

# %% [markdown]
# ## average

# %%
num1=int(input("enter first number:"))
num2=int(input("enter first number:"))
num3=int(input("enter first number:"))
num4=int(input("enter first number:"))
num5=int(input("enter first number:"))
print((num1+num2+num3+num4+num5)/5)
# Out:
# enter first number:2
# enter first number:4
# enter first number:5
# enter first number:6
# enter first number:8
# 5.0
