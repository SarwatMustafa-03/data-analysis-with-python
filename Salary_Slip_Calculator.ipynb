# %% [markdown]
# <a href="https://colab.research.google.com/github/SarwatMustafa-03/data-analysis-with-python/blob/main/Salary_Slip_Calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
employee_name=input("Enter Your Name:")
basic_salary=float(input("Enter Your Basic Salary:"))
bonus_amount=float(input("Enter Your Bonus Amount:"))
tax_percentage=float(input("Enter Your Tax %:"))


###Calculation
gross_salary=basic_salary+bonus_amount
tax_amount=(gross_salary*tax_percentage)/100
net_salary=gross_salary-tax_amount


###Output
print("---Salary Slip---")
print("Employee Name:",employee_name)
print("Basic Salary:",basic_salary)
print("Bonus Amount:",bonus_amount)
print("Tax Percentage:",tax_percentage)

print("Gross Salary:", gross_salary)
print("Tax Amount:", tax_amount)
print("Net Salary:", net_salary)
# Out:
# Enter Your Name:sarwat
# Enter Your Basic Salary:25000
# Enter Your Bonus Amount:1000
# Enter Your Tax %:2.6
# ---Salary Slip---
# Employee Name: sarwat
# Basic Salary: 25000.0
# Bonus Amount: 1000.0
# Tax Percentage: 2.6
# Gross Salary: 26000.0
# Tax Amount: 676.0
# Net Salary: 25324.0
