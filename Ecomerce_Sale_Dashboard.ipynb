# %% [markdown]
# <a href="https://colab.research.google.com/github/SarwatMustafa-03/data-analysis-with-python/blob/main/Ecomerce_Sale_Dashboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install pandas numpy matplotlib seaborn

# %%
print(pd.__version__)
print(np.__version__)
# Out:
# 2.2.3
# 2.1.3

# %%
from google.colab import files

files.download('/content/sample_data/california_housing_train.csv')

# %%
import pandas as pd

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0

# %%
df.shape
# Out:
# (17000, 9)

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
import pandas as pd

df = pd.read_csv('/content/sample_data/california_housing_train.csv')

print(f"Max median_income: {df['median_income'].max()}")
print(f"Min median_income: {df['median_income'].min()}")
print(f"Mean median_income: {df['median_income'].mean()}")
# Out:
# Max median_income: 15.0001
# Min median_income: 0.4999
# Mean median_income: 3.8835781000000007

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
df.nunique()
# Out:
# longitude               827
# latitude                840
# housing_median_age       52
# total_rooms            5533
# total_bedrooms         1848
# population             3683
# households             1740
# median_income         11175
# median_house_value     3694
# dtype: int64

# %%
df["median_house_value"].head()
# Out:
# 0    66900.0
# 1    80100.0
# 2    85700.0
# 3    73400.0
# 4    65500.0
# Name: median_house_value, dtype: float64

# %%
df[df["median_house_value"] > 300000]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 172      -116.26     33.65                 3.0       7437.0          1222.0
# 187      -116.33     33.72                11.0      12327.0          2000.0
# 193      -116.37     33.69                 7.0       8806.0          1542.0
# 210      -116.42     33.76                14.0      16921.0          2837.0
# 215      -116.43     33.75                24.0       2596.0           438.0
# ...          ...       ...                 ...          ...             ...
# 16642    -122.73     38.26                35.0       3941.0           645.0
# 16672    -122.78     38.44                14.0       4143.0           656.0
# 16694    -122.82     38.44                23.0       1551.0           236.0
# 16715    -122.85     38.37                16.0       1762.0           293.0
# 16776    -123.00     38.33                 8.0       3223.0           637.0
#
# ...

# %%
import pandas as pd

df = pd.read_csv('/content/sample_data/california_housing_train.csv')
(df.isnull().sum() / len(df)) * 100
# Out:
# longitude             0.0
# latitude              0.0
# housing_median_age    0.0
# total_rooms           0.0
# total_bedrooms        0.0
# population            0.0
# households            0.0
# median_income         0.0
# median_house_value    0.0
# dtype: float64

# %%
df["median_income"].head()
# Out:
# 0    1.4936
# 1    1.8200
# 2    1.6509
# 3    3.1917
# 4    1.9250
# Name: median_income, dtype: float64

# %%
(df < 0).sum()
# Out:
# longitude             17000
# latitude                  0
# housing_median_age        0
# total_rooms               0
# total_bedrooms            0
# population                0
# households                0
# median_income             0
# median_house_value        0
# dtype: int64

# %%
df["total_bedrooms"] = df["total_bedrooms"].fillna(
    df["total_bedrooms"].median()
)

# %%
import pandas as pd

df = pd.read_csv('/content/sample_data/california_housing_train.csv')

# New analytical columns
df["rooms_per_household"] = df["total_rooms"] / df["households"]

df["bedrooms_per_household"] = df["total_bedrooms"] / df["households"]

df["population_per_household"] = df["population"] / df["households"]

# Show first 5 rows
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value  \
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0
#
#    rooms_per_household  bedrooms_per_household  population_per_household
# 0            11.889831                2.718220                  2.150424
# ...

# %%
# LOC - column name se
print("Using loc:")
print(df.loc[:, "median_income"].head())

# ILOC - column position se
print("\nUsing iloc:")
print(df.iloc[:, 7].head())
# Out:
# Using loc:
# 0    1.4936
# 1    1.8200
# 2    1.6509
# 3    3.1917
# 4    1.9250
# Name: median_income, dtype: float64
#
# Using iloc:
# 0    1.4936
# 1    1.8200
# 2    1.6509
# 3    3.1917
# 4    1.9250
# Name: median_income, dtype: float64
